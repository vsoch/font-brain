# %% [markdown]
# # Journal Counts for Pubmed (PMC) FTP

# %%
import pandas
pandas.set_option('display.max_rows', 5500)
counts = pandas.read_pickle("journal_counts.pkl")

# %%
counts
# Out:
# PLoS One                                                        123685
# Acta Crystallogr Sect E Struct Rep Online                        23487
# J Cell Biol                                                      23311
# J Exp Med                                                        22963
# Br J Cancer                                                      22591
# Environ Health Perspect                                          14749
# Crit Care                                                        14097
# Nucleic Acids Res                                                13389
# Sci Rep                                                           9920
# J Gen Physiol                                                     8068
# BMC Public Health                                                 8058
# Emerg Infect Dis                                                  7850
# BMC Genomics                                                      7734
# ...
